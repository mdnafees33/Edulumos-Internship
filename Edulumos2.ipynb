# %% [markdown]
# <a href="https://colab.research.google.com/github/mdnafees33/Edulumos-Internship/blob/main/Edulumos2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="darkgrid")
plt.rcParams['figure.figsize'] = (10, 6)

# %%
df = pd.read_csv("/content/mymoviedb.csv", engine='python', on_bad_lines='skip')

# %%
print("📄 First 5 Rows:")
print(df.head())
# Out:
# 📄 First 5 Rows:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954       8940
# 1  In his second year of fighting crime, Batman u...    3827.658       1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087        122
# 3  The tale of an extraordinary family, the Madri...    2402.201       5076
# 4  As a collection of history's worst tyrants and...    1895.511       1793
#
#   Vote_Average Original_Language                               Genre  \
# 0          8.3                en  Action, Adventure, Science Fiction
# 1          8.1                en            Crime, Mystery, Thriller
# ...

# %%
print("\n📊 Dataset Info:")
df.info()
# Out:
# 📊 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9837 non-null   object
#  1   Title              9828 non-null   object
#  2   Overview           9828 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   object
#  5   Vote_Average       9827 non-null   object
#  6   Original_Language  9827 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9826 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 691.8+ KB

# %%
print("\n🔍 Missing Values:")
print(df.isnull().sum())
# Out:
# 🔍 Missing Values:
# Release_Date          0
# Title                 9
# Overview              9
# Popularity           10
# Vote_Count           10
# Vote_Average         10
# Original_Language    10
# Genre                11
# Poster_Url           11
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
print(df.columns)
# Out:
# Index(['Release_Date', 'Title', 'Overview', 'Popularity', 'Vote_Count',
#        'Vote_Average', 'Original_Language', 'Genre', 'Poster_Url'],
#       dtype='object')

# %%
print("\n📈 Basic Statistics:")
print(df.describe(include='all'))
# Out:
# 📈 Basic Statistics:
#        Release_Date                 Title  \
# count          9837                  9828
# unique         5903                  9514
# top      2022-03-10  Beauty and the Beast
# freq             16                     4
# mean            NaN                   NaN
# std             NaN                   NaN
# min             NaN                   NaN
# 25%             NaN                   NaN
# 50%             NaN                   NaN
# 75%             NaN                   NaN
# max             NaN                   NaN
#
#                                                  Overview   Popularity  \
# count                                                9828  9827.000000
# unique                                               9823          NaN
# top     Dr. Raichi is one of the only survivors of the...          NaN
# freq                                                    2          NaN
# mean                                                  NaN    40.320570
# ...

# %%
df['release_year'] = pd.to_numeric(df['Release_Date'].str.split('-').str[0], errors='coerce')
plt.figure(figsize=(25, 6))
sns.countplot(data=df, x='release_year', palette='pastel', order=df['release_year'].value_counts().sort_index().index)
plt.title("Content Added by Release Year")
plt.xlabel("Release Year")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipython-input-3645827478.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='release_year', palette='pastel', order=df['release_year'].value_counts().sort_index().index)

# %%
df['Vote_Average'] = pd.to_numeric(df['Vote_Average'], errors='coerce')
plt.figure(figsize=(6, 6))
sns.histplot(data=df, x='Vote_Average', bins=20, kde=True, color='skyblue')
plt.title("Distribution of Vote Average")
plt.xlabel("Vote Average")
plt.ylabel("Frequency")
plt.show()

# %%
df['Genre'] = df['Genre'].fillna("")
genres = df['Genre'].str.split(', ').explode().value_counts().head(10)
plt.figure(figsize=(6, 6))
sns.barplot(x=genres.values, y=genres.index, palette='viridis')
plt.title("Top 10 Popular Genres")
plt.xlabel("Number of Titles")
plt.ylabel("Genre")
plt.show()
# Out:
# /tmp/ipython-input-353515672.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=genres.values, y=genres.index, palette='viridis')

# %%
print("\n📊 Summary Insights:")
print(f"- Total Titles: {len(df)}")
print(f"- Number of Countries: N/A (Country column not available)")
print(f"- Most Common Rating (Vote Average): {df['Vote_Average'].mode()[0]}")
print(f"- Most Common Genre: {genres.index[0]}")

print("\n✅ Data analysis and visualization complete!")
# Out:
# 📊 Summary Insights:
# - Total Titles: 9837
# - Number of Countries: N/A (Country column not available)
# - Most Common Rating (Vote Average): 6.4
# - Most Common Genre: Drama
#
# ✅ Data analysis and visualization complete!
